# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd/content/drive/MyDrive/test_folder/haeryeong1117
# Out:
# /content/drive/MyDrive/test_folder/haeryeong1117

# %%
# !git config --global user.email 'haeryeonglee@naver.com'
# !git config --global user.name 'haeryeong1117'

# %%
! git add hrcolab.ipynb
# Out:
# fatal: pathspec 'hrcolab.ipynb' did not match any files
